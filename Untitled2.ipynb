# %% [markdown]
# <a href="https://colab.research.google.com/github/febajayasing21-ui/Training1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r=int(input("No of rats:"))
u=int(input("No of units:"))
n=int(input("No of elements:"))
arr=list(map(int,input("Enter array").split()))
sum=0
h=0
for i in range(0,len(arr)):
  h+=1
  sum=sum+arr[i]
  if sum>=r*u:
    break
print("No of houses:",h)
# Out:
# No of rats:7
# No of units:2
# No of elements:8
# Enter array2 8 3 5 7 4 1 2
# No of houses: 4
