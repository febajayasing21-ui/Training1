# %% [markdown]
# <a href="https://colab.research.google.com/github/febajayasing21-ui/Training1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=input("enter a string")
print(n[::-1])
# Out:
# enter a stringhello
# olleh

# %%
n=int(input("enter your number:"))
rev=0
while n>0:
  num=n%10
  rev=rev*10+num
  n=n//10
  print("reversed number is:",rev)
# Out:
# enter your number:23
# reversed number is: 3
# reversed number is: 32

# %%
n=int(input("enter a number"))
temp=0
while(n>0):
 r=n%10
 temp=temp+r
 n=n//10
print(temp)
# Out:
# enter a number12
# 3

# %%
n = int(input("enter a number: "))
l= 0
while n > 0:
    r= n % 10
    if r >l:
        l= r
    n= n // 10
print("largest digit =",l)
# Out:
# enter a number: 23
# largest digit = 3

# %%
n=int(input("Enter a number:"))
a=n
t=0
while(n>0):
  r=n%10
  t=(t*10)+r
  n=n//10
if(a==t):
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter a number:202
# Palindrome

# %%
n=input("enter a string:")
if n==n[::-1]:
  print("palindrome")
else:
  print("not a palindrome")
# Out:
# enter a string:malayalam
# palindrome

# %%
str1=input("enter the first string:")
str2=input("enter the second string:")
if sorted(str1)==sorted(str2):
  print("Anagram")
else:
  print("Not Anagram")
# Out:
# enter the first string:listen
# enter the second string:silent
# Anagram

# %%
str=input("Enter a string: ")
print("Length of string with built in:",len(str))
count=0
for i in str:
  count=count+1
print("Length of string without built in:",count)
# Out:
# Enter a string: hello
# Length of string with built in: 5
# Length of string without built in: 5

# %%
s=input("enter a string:")
result=""
for i in s:
  if(i not in result):
    result+=i
    print("after remopving duplicates",result)
# Out:
# enter a string:hello
# after remopving duplicates h
# after remopving duplicates he
# after remopving duplicates hel
# after remopving duplicates helo

# %%
n=input("enter the string :")
v=0
c=0
for i in n:
 if(i in "aeiouAEIOU"):
   v+=1
 else:
   c+=1
print("no. of vowels =",v)
print("no. of consnant =",c)
# Out:
# enter the string :feba
# no. of vowels = 2
# no. of consnant = 2

# %%
a=input("Enter string:")
b=""
for i in a:
    if i!=" ":
        b=b+i
print("String without whitespace:",b)
# Out:
# Enter string:hello Feba
# String without whitespace: helloFeba
