# %% [markdown]
# <a href="https://colab.research.google.com/github/febajayasing21-ui/Training1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  x=int(input("enter the element"))
  arr.append(x)
  print(arr)
print("the largest element is",max(arr))
# Out:
# enter the number of elements4
# enter the element2
# [2]
# enter the element5
# [2, 5]
# enter the element9
# [2, 5, 9]
# enter the element4
# [2, 5, 9, 4]
# the largest element is 9

# %%
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  x=int(input("enter the element"))
  arr.append(x)
  print(arr)
# Out:
# enter the number of elements4
# enter the element3
# [3]
# enter the element2
# [3, 2]
# enter the element7
# [3, 2, 7]
# enter the element5
# [3, 2, 7, 5]

# %%
a=int(input("Enter the number of elements"))
sum=0
for i in range(a):
  b=int(input("Enter the element"))
  sum=sum+b
print("The sum of elements is",sum)
# Out:
# Enter the number of elements4
# Enter the element2
# Enter the element5
# Enter the element9
# Enter the element4
# The sum of elements is 20

# %%
arr=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  a=int(input("Enter element: "))
  arr.append(a)
print("Reversed Array",arr[::-1])
# Out:
# Enter the number of elements: 4
# Enter element: 2
# Enter element: 6
# Enter element: 4
# Enter element: 3
# Reversed Array [3, 4, 6, 2]

# %%
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  m=int(input("enter the element"))
  arr.append(m)
  print(arr)
print("the smallest element is",min(arr))
# Out:
# enter the number of elements4
# enter the element2
# [2]
# enter the element5
# [2, 5]
# enter the element6
# [2, 5, 6]
# enter the element8
# [2, 5, 6, 8]
# the smallest element is 2

# %%
a=int(input("Enter the list size:"))
list=[]
for i in range(a):
  b=int(input("enter the elements:"))
  list.append(b)
k=int(input("Enter an element to be searched:"))
if k in list:
    print("Element exist!")
else:
    print("Element not exist!")
# Out:
# Enter the list size:3
# enter the elements:2
# enter the elements:4
# enter the elements:7
# Enter an element to be searched:8
# Element not exist!

# %%
lst = []
x = int(input("Enter limit: "))
for i in range(x):
    lst.append(int(input("Enter item: ")))
y = int(input("Enter element: "))
count = lst.count(y)
print("Occurrences:", count)
# Out:
# Enter limit: 4
# Enter item: 3
# Enter item: 5
# Enter item: 3
# Enter item: 4
# Enter element: 3
# Occurrences: 2

# %%
n = int(input("Enter number of elements: "))
a = []
for i in range(n):
    a.append(int(input("Enter element: ")))
a.sort()
print("Second largest:", a[-2])
# Out:
# Enter number of elements: 4
# Enter element: 3
# Enter element: 5
# Enter element: 2
# Enter element: 4
# Second largest: 4

# %%
arr=[]
n=int(input("Enter the number of list elements :"))
for i in range(n):
  a=input("Enter elements")
  arr.append(a)
  arr.sort()
print(arr)
# Out:
# Enter the number of list elements :4
# Enter elements3
# Enter elements5
# Enter elements6
# Enter elements2
# ['2', '3', '5', '6']

# %%
n = int(input("Enter the number of elements: "))
a = []

for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)

print("Original list:", a)

result = []
for num in a:
    if num not in result:
        result.append(num)

print("List after removing duplicates:", result)
# Out:
# Enter the number of elements: 5
# Enter the element: 10
# Enter the element: 20
# Enter the element: 10
# Enter the element: 20
# Enter the element: 30
# Original list: [10, 20, 10, 20, 30]
# List after removing duplicates: [10, 20, 30]

# %%
n = int(input("Enter number of elements: "))
arr = [int(x) for x in input("Enter elements: ").split()]
print("array:",arr)
# Out:
# Enter number of elements: 3
# Enter elements: 2  3  4
# array: [2, 3, 4]

# %%
arr=[5,10,15,20,15,30]
print(arr[:])
print(arr[2:])
print(arr[:3])
print(arr[: :-1])
print(arr[1:4])
print(arr[1:5:2])
# Out:
# [5, 10, 15, 20, 15, 30]
# [15, 20, 15, 30]
# [5, 10, 15]
# [30, 15, 20, 15, 10, 5]
# [10, 15, 20]
# [10, 20]
